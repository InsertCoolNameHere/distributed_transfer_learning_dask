# %%
from random import sample
from time import time
import pandas as pd
import pymongo
from sklearn import ensemble
import numpy as np
import os
from sklearn.model_selection import cross_val_score, train_test_split, KFold
from sklearn.metrics import mean_squared_error
from math import sqrt

import random

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV

# %% [markdown]
# <h3><u>GROUPING CLUSTERS FROM CSV</u></h3>

# %%
df_clusters = pd.read_csv("/tmp/clusters.csv")

# %%
time1 = time()

df_clusters

gk = df_clusters.groupby('cluster_id')

gk

# %%
parent_maps = {}
child_to_parent = {}

for name, group in gk:
    row = group[group.distance == group.distance.min()]
    row_max = group[group.distance == group.distance.max()]
    
    children = list(group.gis_join)
    distances = list(group.distance)
    
    dist_min = row['distance'].item()
    dist_max = row_max['distance'].item()
    
    pg = str(row['gis_join'].item())
    
    parent_index = children.index(pg)
    children.pop(parent_index)
    distances.pop(parent_index)
    
    inner_dict = {}
    inner_dict['dist_min'] = dist_min
    inner_dict['dist_max'] = dist_max
    inner_dict['children'] = children
    inner_dict['distances'] = distances
    
    parent_maps[pg] = inner_dict
    
    for c in children:
        child_to_parent[c] = pg
    
                           
print(parent_maps)
print(child_to_parent)
# Out:
# {'G0800650': {'dist_min': 391.0929075096816, 'dist_max': 424.1308766333965, 'children': ['G2101030', 'G4500330', 'G1301150', 'G3700070', 'G4701890', 'G0100470', 'G0801050', 'G5105200', 'G3900970', 'G1301810', 'G4500210', 'G2600910', 'G2400390', 'G3000870', 'G0600950', 'G1700210', 'G0100930', 'G1801190', 'G2002030', 'G3701990', 'G3000650', 'G2001750', 'G4200890', 'G1301630', 'G1301770', 'G2701010', 'G5500190', 'G5000030', 'G2701190', 'G2800590', 'G1701790', 'G4600370', 'G2001690', 'G1300390', 'G2601650', 'G3701330', 'G4800290', 'G2801550', 'G0800930', 'G1701930', 'G4000830', 'G4802930', 'G5101870', 'G3500030', 'G4500490', 'G1200610', 'G3800630', 'G4801950', 'G2400310', 'G1302330', 'G5400390', 'G2000790', 'G3100170', 'G1801770', 'G5300330', 'G4600130', 'G3900290', 'G2600610', 'G2002090', 'G4100330', 'G2801250', 'G4200150', 'G1600230', 'G1300470', 'G5400110', 'G4800230', 'G1800170', 'G5101190', 'G5101270', 'G5101490', 'G4701590', 'G4000670', 'G3701150', 'G3701490', 'G3000370', 'G4800650', 'G2601290', 'G4803970', 'G0800890', 'G4100150', 'G2001990', 'G3300090', 'G4803230', 'G1701690', 'G1302950', 'G4803430', 'G0400150', 'G0800450', 'G2700490', 'G5101610', 'G2000070', 'G3901170', 'G3101710', 'G1301910', 'G2701230', 'G4600110', 'G0600490', 'G0501270', 'G2800230', 'G5600170', 'G3600990', 'G1801110', 'G2700790', 'G5100010', 'G2700590', 'G4900550', 'G1700730', 'G4701150', 'G2200030', 'G3400270', 'G1701250', 'G1300030', 'G5300210', 'G3701930', 'G2901870', 'G0601130', 'G4000210', 'G2200250', 'G2200550', 'G5100990', 'G1700070', 'G0500070', 'G0500510', 'G2600270', 'G5400190', 'G2102370', 'G2600830', 'G4801110', 'G1701890', 'G3500090', 'G4601210', 'G5500530', 'G2902170', 'G2001610', 'G2102010', 'G5300110', 'G4800890', 'G0800290', 'G3600970', 'G4700430', 'G3000950', 'G2901970', 'G4500450', 'G2300090', 'G5500850', 'G5600190', 'G0801210', 'G0500490', 'G4801550', 'G5400770', 'G0801110', 'G0400190', 'G3701530', 'G5300570', 'G5500390', 'G4001490', '
': 'G0800650', 'G3701530': 'G0800650', 'G5300570': 'G0800650', 'G5500390': 'G0800650', 'G4001490': 'G0800650', 'G1302690': 'G0800650', 'G2000890': 'G0800650', 'G2300110': 'G0800650', 'G3500280': 'G0800650', 'G0800010': 'G0800650', 'G4000010': 'G0800650', 'G2001270': 'G0800650', 'G2800830': 'G0800650', 'G4700630': 'G0800650', 'G3800830': 'G0800650', 'G3101330': 'G0 ...

# %% [markdown]
# <h3><u>CONSTANTS AND HELPER FUNCTIONS</u></h3>

# %%
sample_min = 0.05
sample_max = 0.25

query_collection = "macav2"

mongo_urls = [
    'mongodb://lattice-100:27018/',
    'mongodb://lattice-101:27018/',
    'mongodb://lattice-102:27018/',
    'mongodb://lattice-103:27018/',
    'mongodb://lattice-104:27018/'
]

mongo_db_name = "sustaindb"
query_fild = "gis_join"
train_test = 0.8


training_labels = ["min_surface_downwelling_shortwave_flux_in_air", "max_surface_downwelling_shortwave_flux_in_air",
                   "max_specific_humidity", "min_max_air_temperature", "max_max_air_temperature"]
target_labels = ["max_min_air_temperature"]


# QUERY projection
client_projection = {}
for val in training_labels:
    client_projection[val] = 1
for val in target_labels:
    client_projection[val] = 1

# %% [markdown]
# <h1><u>MODELING</u></h1>

# %%
saved_models = {}

# ACTUAL QUERYING
def query_sustaindb(query_gisjoin, sustain_db):
    sustain_collection = sustain_db[query_collection]
    client_query = {query_fild: query_gisjoin}
    query_results = list(sustain_collection.find(client_query, client_projection)) 
    return list(query_results)

# SAMPLE FROM QUERY RESULTS
def data_sampling(query_results, exhaustive, sample_percent=1):
    if exhaustive:
        all_data = query_results
    else:
        data_size = int(len(query_results) * sample_percent)
        all_data = sample(query_results, data_size)

    return pd.DataFrame(all_data)

# GET SAMPLE % BASED ON DISTANCE FROM CENTROID
def get_sample_percent(gis_join):
    parent_gis = child_to_parent[gis_join]
    inner_dict = parent_maps[parent_gis]
    d_max = inner_dict['dist_max']
    d_min = inner_dict['dist_min']
    children = inner_dict['children']
    distances = inner_dict['distances']
    
    my_index = children.index(gis_join)
    my_distance = distances[my_index]
    
    frac = (my_distance - d_min)/(d_max - d_min)
    
    perc = sample_min + (sample_max - sample_min) * frac
    
    perc*=100
    perc = int(perc)
    perc = perc - (perc%5)
    
    perc = perc/100
    return perc


# GET PERCENTAGE DISTANCE FROM CENTROID
def get_distance_percentage(gis_join):
    parent_gis = child_to_parent[gis_join]
    inner_dict = parent_maps[parent_gis]
    d_max = inner_dict['dist_max']
    d_min = inner_dict['dist_min']
    children = inner_dict['children']
    distances = inner_dict['distances']
    
    my_index = children.index(gis_join)
    my_distance = distances[my_index]
    
    frac = (my_distance - d_min)/(d_max - d_min)
    
    return frac * 100

def exhaustive_training(X,Y, gis_join):
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
    
    param_grid = {'max_depth': [2, 3], 'min_samples_split': [15, 20, 50]}
#     base_est = ensemble.RandomForestRegressor(random_state=0)
    base_est = ensemble.GradientBoostingRegressor(random_state=0)
    sh = HalvingGridSearchCV(base_est, param_grid, cv=5, verbose=1, 
                             factor=2, resource='n_estimators', max_resources=600).fit(X, pd.Series.ravel(Y))
    
    clf_best = sh.best_estimator_
    rmse = sqrt(mean_squared_error(pd.Series.ravel(y_test), clf_best.predict(X_test)))
    
    print("PARENT GISJOIN: ", gis_join, "RMSE:", rmse)
    return clf_best
    

def sampled_training(X, Y, gis_join, saved_models):
    parent_gis = child_to_parent[gis_join]
    clf = saved_models[parent_gis]
    
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
    
    clf.fit(X_train, pd.Series.ravel(y_train))

    rmse = sqrt(mean_squared_error(pd.Series.ravel(y_test), clf.predict(X_test)))
    
    print("CHILD GISJOIN: ", gis_join, "RMSE:", rmse)
    return clf
    

def train_gisjoin(gis_join, exhaustive=True, saved_models={}):
    mongo_url = mongo_urls[random.randint(0, len(mongo_urls) - 1)]
    sustainclient = pymongo.MongoClient(mongo_url)
    sustain_db = sustainclient[mongo_db_name]

    sample_percent = 1
    if not exhaustive:
        #print("SAMPLED CHILD TRAINING.....")
        sample_percent = get_sample_percent(gis_join)
        
        
    #QUERY
    results = query_sustaindb(gis_join, sustain_db)
    
    df_sampled = data_sampling(results, exhaustive, sample_percent)
    
    Y = df_sampled.loc[:,target_labels]
    X = df_sampled.loc[:, training_labels]
    #print(X.shape, Y.shape)
    
    if exhaustive:
        clf = exhaustive_training(X,Y, gis_join)
    else:
        clf = sampled_training(X,Y, gis_join, saved_models)
    
    #saved_models[gis_join] = clf
    return (gis_join,clf)
    
#'G1303070': 'G0800010'
#train_gisjoin('G0800010', True)
#train_gisjoin('G1303070', False)

# %%
sampling_perc_to_children_map = {}
for ck in child_to_parent.keys():
    perc = get_distance_percentage(ck)
    sampling_perc_to_children_map[ck] = perc
    
keys_0_to_15 = []
keys_15_to_25 = []
    
for gis_join, perc in sampling_perc_to_children_map.items():
    if perc < 15:
        keys_0_to_15.append(gis_join)
    elif perc > 15:
        keys_15_to_25.append(gis_join)
    
print(f'keys_0_to_15: {len(keys_0_to_15)}')
print(f'keys_15_to_25: {len(keys_15_to_25)}')
# Out:
# keys_0_to_15: 90
# keys_15_to_25: 3016

# %%
import dask
from dask import delayed
from dask.distributed import Client

client = Client('localhost:9010')
# Out:
# /s/parsons/b/others/sustain/.local/lib/python3.8/site-packages/distributed/client.py:1183: VersionMismatchWarning: Mismatched versions found
#
# +-------------+---------------+----------------+----------------+
# | Package     | client        | scheduler      | workers        |
# +-------------+---------------+----------------+----------------+
# | blosc       | 1.10.4        | 1.10.2         | 1.10.2         |
# | dask        | 2021.07.0     | 2021.08.0      | 2021.08.0      |
# | distributed | 2021.07.0     | 2021.08.0      | 2021.08.0      |
# | numpy       | 1.21.0        | 1.21.1         | 1.21.1         |
# | python      | 3.8.6.final.0 | 3.8.10.final.0 | 3.8.10.final.0 |
# +-------------+---------------+----------------+----------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
outputs = []

# TRAINING PARENTS FIRST
for pk in parent_maps.keys():
    ret = delayed(train_gisjoin)(pk,True)
    outputs.append(ret)

futures = dask.persist(*outputs)  # trigger computation in the background
results = dask.compute(*futures)

# %%
print(results)
# Out:
# (('G0800650', GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G0600750', GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)))

# %%
for sm in results:
    (gis_join, model) = sm
    saved_models[gis_join] = model

print(saved_models)
# Out:
# {'G0800650': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0600750': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)}

# %%
# client = Client('localhost:9010')
outputs2 = []

# TRAINING CHILDREN NEXT
# for ck in child_to_parent.keys():
for ck in keys_0_to_15:
    ret = delayed(train_gisjoin)(ck, False, saved_models)
    outputs2.append(ret)

futures2 = dask.persist(*outputs2)  # trigger computation in the background
results2 = dask.compute(*futures2)

for sm in results2:
    (gis_join, model) = sm
    saved_models[gis_join] = model

print(saved_models)
# Out:
# {'G0800650': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0600750': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0801050': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2701190': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800630': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5500850': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0801110': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800830': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800570': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2701130': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800470': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0800790': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5500410': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800170': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800130': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800670': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800090': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800610': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700270': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800730': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700710': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800230': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700010': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800510': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5500690': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0800530': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5501190': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5500670': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700610': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2600710': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5600350': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2701070': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0800570': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800970': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800490': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2600430': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5501250': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800190': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3801010': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800930': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700290': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800030': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700690': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0800470': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5500370': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700050': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5000090': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800430': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2300210': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5500990': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800790': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1600810': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5500510': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0801170': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800990': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3801030': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700650': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5600230': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800910': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800750': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0800190': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700570': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700770': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2701350': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800390': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800350': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800450': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2701250': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800950': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5600390': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3000230': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700210': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2300030': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800310': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3000910': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2701590': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0800490': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5501130': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700310': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800690': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800050': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5000050': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700070': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G5000190': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3000190': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700890': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700350': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800710': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700170': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2700870': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800550': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3800270': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)}

# %%
import dask
from dask import delayed
from dask.distributed import Client
client = Client('localhost:9020')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 96

# %%
outputs3 = []

# TRAINING CHILDREN NEXT
# for ck in child_to_parent.keys():
for ck in keys_15_to_25:
    ret = delayed(train_gisjoin)(ck, False, saved_models)
    outputs3.append(ret)

futures3 = dask.persist(*outputs3)  # trigger computation in the background
results3 = dask.compute(*futures3)

for sm in results3:
    (gis_join, model) = sm
    saved_models[gis_join] = model

print(saved_models)
time2 = time()

# %%
print(f'Time Taken: {time2 - time1} s')
