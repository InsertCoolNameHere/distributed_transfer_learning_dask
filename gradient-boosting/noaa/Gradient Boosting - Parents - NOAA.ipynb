# %%
from random import sample
from time import time
import pandas as pd
import pymongo
from sklearn import ensemble
import numpy as np
import os
from sklearn.model_selection import cross_val_score, train_test_split, KFold
from sklearn.metrics import mean_squared_error
from math import sqrt

import random

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV

import pickle

# %% [markdown]
# <h3><u>GROUPING CLUSTERS FROM CSV</u></h3>

# %%
df_clusters = pd.read_csv("~/ucc-21/clusters-noaa.csv")

# %%
time1 = time()

df_clusters

gk = df_clusters.groupby('cluster_id')

gk

# %%
parent_maps = {}
child_to_parent = {}

for name, group in gk:
    row = group[group.distance == group.distance.min()]
    row_max = group[group.distance == group.distance.max()]
    
    children = list(group.gis_join)
    distances = list(group.distance)
    
    dist_min = row['distance'].item()
    dist_max = row_max['distance'].item()
    
    pg = str(row['gis_join'].item())
    
    parent_index = children.index(pg)
    children.pop(parent_index)
    distances.pop(parent_index)
    
    inner_dict = {}
    inner_dict['dist_min'] = dist_min
    inner_dict['dist_max'] = dist_max
    inner_dict['children'] = children
    inner_dict['distances'] = distances
    
    parent_maps[pg] = inner_dict
    
    for c in children:
        child_to_parent[c] = pg
    
                           
print(parent_maps)
print(child_to_parent)
# Out:
# {'G5501210': {'dist_min': 46.36862986120119, 'dist_max': 862.0309874525391, 'children': ['G3700970', 'G3900970', 'G1801390', 'G4000990', 'G2701190', 'G3900370', 'G2700190', 'G2600450', 'G2701070', 'G5500210', 'G2900910', 'G4700650', 'G5500650', 'G4001330', 'G4802370', 'G3900270', 'G2701570', 'G5501310', 'G2600750', 'G5501370', 'G0100490', 'G4001370', 'G3900910', 'G5500950', 'G2600930', 'G5500150', 'G5500350', 'G2901790', 'G3700450', 'G1900190', 'G5500630', 'G1801770', 'G1800870', 'G5501090', 'G3900210', 'G1801510', 'G1900430', 'G4800990', 'G4000190', 'G5501030', 'G1800350', 'G3901170', 'G5500470', 'G0500970', 'G0501270', 'G4000670', 'G5501050', 'G0501130', 'G5500530', 'G5501410', 'G3800670', 'G1900050', 'G2701630', 'G2900930', 'G2701230', 'G2601490', 'G3900710', 'G2700790', 'G1302950', 'G5500550', 'G3900110', 'G4001250', 'G2701150', 'G4804850', 'G5501110', 'G1800750', 'G5500770', 'G2701710', 'G2700690', 'G5500010', 'G2601170', 'G5500810', 'G5501350', 'G1800410', 'G3901590', 'G5500930', 'G2700250', 'G1800650', 'G4803630', 'G5501270', 'G5500230', 'G5500330', 'G5500490', 'G2600770', 'G2600590', 'G1300830', 'G2700590', 'G2902030', 'G2700550', 'G5500110', 'G3700030', 'G2100450', 'G2902210', 'G3700350', 'G3900890', 'G5500170', 'G4800770', 'G1900550', 'G5500250', 'G5501230', 'G4001230', 'G4800090', 'G1801350', 'G3901010', 'G5500390', 'G3901350', 'G2700370', 'G2700890', 'G2600230', 'G0501410', 'G1801130', 'G5500570', 'G5500450', 'G2600150', 'G1900610', 'G2700030', 'G5500270', 'G3900310', 'G1701110', 'G3900650', 'G3900330', 'G5500970', 'G2600250', 'G1800330', 'G4000330', 'G1800110', 'G0501370', 'G2701390', 'G3901090', 'G5500430', 'G0600110', 'G0601150', 'G5500910', 'G0100710', 'G4000490', 'G3901490', 'G0500710', 'G1801610', 'G2601230', 'G3900570', 'G3900470', 'G2700650', 'G3900230', 'G4803670', 'G2600650', 'G2700530', 'G4000870', 'G5500130', 'G2701690', 'G5501330', 'G2701410'], 'distances': [202.3326773352675, 378.50519694762914, 413.23396550783264, 90.33595694594754, 617.155318200238, 289.29128949250963, 306.7044765266368, 355.861681261179, 543.0949472802357, 163.49855319674978, 400.1494733100312, 293.98568591480205, 282.37857874763563, 446.48820250625255, 456.1456397319324, 390.7138199753375, 288.47097686546107, 92.03329205409028, 270.9987123606591, 178.75497583252806, 504.5664978322587, 376.1165894835471, 409.14425786350193, 623.3782250975136, 454.81018111107096, 472.6378611358629, 119.53199433936445, 337.4701579146076, 395.6061607853118, 373.8107358900117, 272.5369100508918, 253.60237650885915, 322.2627335156741, 371.51727556644187, 472.4501826308268, 78.84349864990715, 290.57714617127874, 414.5252993033262, 291.9085537299175, 91.06231578423396, 289.0234253309144, 527.7883140899377, 364.7634116642631, 443.91028321745785, 403.967206114968, 392.0888360189026, 374.7553829801532, 302.4321725955152, 135.55814703164856, 527.56800777406, 714.7838919237237, 230.74820027419293, 150.7564922219007, 289.0013031715658, 212.8725539474044, 488.2187637478533, 457.10042972264927, 425.61607563448655, 421.644343095593, 432.8808421909188, 424.5342691740268, 374.3045500584491, 620.5824365685776, 417.9477846395643, 101.52699168942172, 408.3584799039149, 388.1967102048957, 410.3255812385006, 639.1883872382132, 98.56046776378778, 474.49438200298925, 336.5371576117103, 360.787370735412, 286.61103889944394, 345.3255051759049, 245.0845639473445, 126.6737473884597, 230.30103456278897, 427.1352076774576, 202.06686584494724, 233.32397647716144, 153.93938131108206, 291.8742301849081, 385.1019207985997, 227.54190502516337, 475.3615135548768, 155.92505126678276, 331.3629298823292, 225.7537255301876, 104.11030332016026, 667.50994973643, 528.2724246001258, 420.07977505502254, 200.55046101043752, 427.17296379935976, 404.5492351637435, 355.2185796578023, 387.230616045596, 182.11986823042224, 237.96123669811945, 164.44584021591683, 447.47735894750014, 325.38768574462176, 392.5625328108894, 128.064769763855, 250.8911046141567, 190.14766093081056, 806.5614124312933, 170. ...
# {'G3700970': 'G5501210', 'G3900970': 'G5501210', 'G1801390': 'G5501210', 'G4000990': 'G5501210', 'G2701190': 'G5501210', 'G3900370': 'G5501210', 'G2700190': 'G5501210', 'G2600450': 'G5501210', 'G2701070': 'G5501210', 'G5500210': 'G5501210', 'G2900910': 'G5501210', 'G4700650': 'G5501210', 'G5500650': 'G5501210', 'G4001330': 'G5501210', 'G4802370': 'G5501210', 'G3900270': 'G5501210', 'G2701570': 'G5501210', 'G5501310': 'G5501210', 'G2600750': 'G5501210', 'G5501370': 'G5501210', 'G0100490': 'G5501210', 'G4001370': 'G5501210', 'G3900910': 'G5501210', 'G5500950': 'G5501210', 'G2600930': 'G5501210', 'G5500150': 'G5501210', 'G5500350': 'G5501210', 'G2901790': 'G5501210', 'G3700450': 'G5501210', 'G1900190': 'G5501210', 'G5500630': 'G5501210', 'G1801770': 'G5501210', 'G1800870': 'G5501210', 'G5501090': 'G5501210', 'G3900210': 'G5501210', 'G1801510': 'G5501210', 'G1900430': 'G5501210', 'G4800990': 'G5501210', 'G4000190': 'G5501210', 'G5501030': 'G5501210', 'G1800350': 'G5501210', 'G3901170': 'G5501210', 'G5500470': 'G5501210', 'G0500970': 'G5501210', 'G0501270': 'G5501210', 'G4000670': 'G5501210', 'G5501050': 'G5501210', 'G0501130': 'G5501210', 'G5500530': 'G5501210', 'G5501410': 'G5501210', 'G3800670': 'G5501210', 'G1900050': 'G5501210', 'G2701630': 'G5501210', 'G2900930': 'G5501210', 'G2701230': 'G5501210', 'G2601490': 'G5501210', 'G3900710': 'G5501210', 'G2700790': 'G5501210', 'G1302950': 'G5501210', 'G5500550': 'G5501210', 'G3900110': 'G5501210', 'G4001250': 'G5501210', 'G2701150': 'G5501210', 'G4804850': 'G5501210', 'G5501110': 'G5501210', 'G1800750': 'G5501210', 'G5500770': 'G5501210', 'G2701710': 'G5501210', 'G2700690': 'G5501210', 'G5500010': 'G5501210', 'G2601170': 'G5501210', 'G5500810': 'G5501210', 'G5501350': 'G5501210', 'G1800410': 'G5501210', 'G3901590': 'G5501210', 'G5500930': 'G5501210', 'G2700250': 'G5501210', 'G1800650': 'G5501210', 'G4803630': 'G5501210', 'G5501270': 'G5501210', 'G5500230': 'G5501210', 'G5500330': 'G5501210', 'G5500490': 'G5501210', 'G2600770': 'G5501210', 'G2600590': 'G5501210', 'G1300830': 'G5501210', 'G2700590': 'G5501210', 'G2902030': 'G5501210', 'G2700550': 'G5501210', 'G5500110': 'G5501210', 'G3700030': 'G5501210', 'G2100450': 'G5501210', 'G2902210': 'G5501210', 'G3700350': 'G5501210', 'G3900890': 'G5501210', 'G5500170': 'G5501210', 'G4800770': 'G5501210', 'G1900550': 'G5501210', 'G5500250': 'G5501210', 'G5501230': 'G5501210', 'G4001230': 'G5501210', 'G4800090': 'G5501210', 'G1801350': 'G5501210', 'G3901010': 'G5501210', 'G5500390': 'G5501210', 'G3901350': 'G5501210', 'G2700370': 'G5501210', 'G2700890': 'G5501210', 'G2600230': 'G5501210', 'G0501410': 'G5501210', 'G1801130': 'G5501210', 'G5500570': 'G5501210', 'G5500450': 'G5501210', 'G2600150': 'G5501210', 'G1900610': 'G5501210', 'G2700030': 'G5501210', 'G5500270': 'G5501210', 'G3900310': 'G5501210', 'G1701110': 'G5501210', 'G3900650': 'G5501210', 'G3900330': 'G5501210', 'G5500970': 'G5501210', 'G2600250': 'G5501210', 'G1800330': 'G5501210', 'G4000330': 'G5501210', 'G1800110': 'G5501210', 'G0501370': 'G5501210', 'G2701390': 'G5501210', 'G3901090': 'G5501210', 'G5500430': 'G5501210', 'G0600110': 'G5501210', 'G0601150': 'G5501210', 'G5500910': 'G5501210', 'G0100710': 'G5501210', 'G4000490': 'G5501210', 'G3901490': 'G5501210', 'G0500710': 'G5501210', 'G1801610': 'G5501210', 'G2601230': 'G5501210', 'G3900570': 'G5501210', 'G3900470': 'G5501210', 'G2700650': 'G5501210', 'G3900230': 'G5501210', 'G4803670': 'G5501210', 'G2600650': 'G5501210', 'G2700530': 'G5501210', 'G4000870': 'G5501210', 'G5500130': 'G5501210', 'G2701690': 'G5501210', 'G5501330': 'G5501210', 'G2701410': 'G5501210', 'G1600730': 'G1600390', 'G3200010': 'G1600390', 'G5300070': 'G1600390', 'G1600830': 'G1600390', 'G4100610': 'G1600390', 'G4100250': 'G1600390', 'G4100450': 'G1600390', 'G4100010': 'G1600390', 'G4100630': 'G1600390', 'G3000990': 'G1600390', 'G0600930': 'G1600390', 'G3000610': 'G1600390', 'G4900450': 'G1600390', 'G4100170': 'G1600390', 'G4100130': 'G1600390', 'G4900530': 'G1 ...

# %% [markdown]
# <h3><u>CONSTANTS AND HELPER FUNCTIONS</u></h3>

# %%
sample_min = 0.05
sample_max = 0.25

query_collection = "noaa_nam_2"

mongo_urls = [
    'mongodb://lattice-100:27018/',
    'mongodb://lattice-101:27018/',
    'mongodb://lattice-102:27018/',
    'mongodb://lattice-103:27018/',
    'mongodb://lattice-104:27018/'
]

mongo_db_name = "sustaindb"
query_fild = "gis_join"
train_test = 0.8


training_labels = ["mean_sea_level_pressure_pascal",
                   "surface_pressure_surface_level_pascal",
                   "10_metre_u_wind_component_meters_per_second",
                   "10_metre_v_wind_component_meters_per_second",
                   "soil_temperature_kelvin"]

target_labels = ["pressure_pascal"]


# QUERY projection
client_projection = {}
for val in training_labels:
    client_projection[val] = 1
for val in target_labels:
    client_projection[val] = 1

# %% [markdown]
# <h1><u>MODELING</u></h1>

# %%
saved_models = {}

# ACTUAL QUERYING
def query_sustaindb(query_gisjoin, sustain_db):
    sustain_collection = sustain_db[query_collection]
    client_query = {query_fild: query_gisjoin}
    query_results = list(sustain_collection.find(client_query, client_projection)) 
    return list(query_results)

# SAMPLE FROM QUERY RESULTS
def data_sampling(query_results, exhaustive, sample_percent=1):
    if exhaustive:
        all_data = query_results
    else:
        data_size = int(len(query_results) * sample_percent)
        all_data = sample(query_results, data_size)

    return pd.DataFrame(all_data)

# GET SAMPLE % BASED ON DISTANCE FROM CENTROID
def get_sample_percent(gis_join):
    parent_gis = child_to_parent[gis_join]
    inner_dict = parent_maps[parent_gis]
    d_max = inner_dict['dist_max']
    d_min = inner_dict['dist_min']
    children = inner_dict['children']
    distances = inner_dict['distances']
    
    my_index = children.index(gis_join)
    my_distance = distances[my_index]
    
    frac = (my_distance - d_min)/(d_max - d_min)
    
    perc = sample_min + (sample_max - sample_min) * frac
    
    perc *= 100
    perc = int(perc)
    perc = perc - (perc % 5)
    
    perc = perc/100
    return perc


# GET PERCENTAGE DISTANCE FROM CENTROID
def get_distance_percentage(gis_join):
    parent_gis = child_to_parent[gis_join]
    inner_dict = parent_maps[parent_gis]
    d_max = inner_dict['dist_max']
    d_min = inner_dict['dist_min']
    children = inner_dict['children']
    distances = inner_dict['distances']
    
    my_index = children.index(gis_join)
    my_distance = distances[my_index]
    
    frac = (my_distance - d_min)/(d_max - d_min)
    
    return frac * 100

def exhaustive_training(X,Y, gis_join):
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
    
    param_grid = {'max_depth': [2, 3], 'min_samples_split': [15, 20, 50]}
#     base_est = ensemble.RandomForestRegressor(random_state=0)
    base_est = ensemble.GradientBoostingRegressor(random_state=0)
    sh = HalvingGridSearchCV(base_est, param_grid, cv=5, verbose=1, 
                             factor=2, resource='n_estimators', max_resources=600).fit(X, pd.Series.ravel(Y))
    
    clf_best = sh.best_estimator_
    rmse = sqrt(mean_squared_error(pd.Series.ravel(y_test), clf_best.predict(X_test)))
    
    print("PARENT GISJOIN: ", gis_join, "RMSE:", rmse)
    return clf_best
    

def sampled_training(X, Y, gis_join, saved_models):
    parent_gis = child_to_parent[gis_join]
    clf = saved_models[parent_gis]
    
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
    
    clf.fit(X_train, pd.Series.ravel(y_train))

    rmse = sqrt(mean_squared_error(pd.Series.ravel(y_test), clf.predict(X_test)))
    
    print("CHILD GISJOIN: ", gis_join, "RMSE:", rmse)
    return clf
    

def train_gisjoin(gis_join, exhaustive=True, saved_models={}):
    mongo_url = mongo_urls[random.randint(0, len(mongo_urls) - 1)]
    sustainclient = pymongo.MongoClient(mongo_url)
    sustain_db = sustainclient[mongo_db_name]

    sample_percent = 1
    if not exhaustive:
        #print("SAMPLED CHILD TRAINING.....")
        sample_percent = get_sample_percent(gis_join)
        
        
    #QUERY
    results = query_sustaindb(gis_join, sustain_db)
    
    df_sampled = data_sampling(results, exhaustive, sample_percent)
    
    Y = df_sampled.loc[:,target_labels]
    X = df_sampled.loc[:, training_labels]
    #print(X.shape, Y.shape)
    
    if exhaustive:
        clf = exhaustive_training(X,Y, gis_join)
    else:
        clf = sampled_training(X,Y, gis_join, saved_models)
    
    #saved_models[gis_join] = clf
    return (gis_join,clf)
    
#'G1303070': 'G0800010'
#train_gisjoin('G0800010', True)
#train_gisjoin('G1303070', False)

# %%
import dask
from dask import delayed
from dask.distributed import Client

client = Client('localhost:9000')
# Out:
# /s/parsons/b/others/sustain/.local/lib/python3.8/site-packages/distributed/client.py:1183: VersionMismatchWarning: Mismatched versions found
#
# +-------------+---------------+----------------+----------------+
# | Package     | client        | scheduler      | workers        |
# +-------------+---------------+----------------+----------------+
# | blosc       | 1.10.4        | 1.10.2         | 1.10.2         |
# | dask        | 2021.07.0     | 2021.08.0      | 2021.08.0      |
# | distributed | 2021.07.0     | 2021.08.0      | 2021.08.0      |
# | numpy       | 1.21.0        | 1.21.1         | 1.21.1         |
# | python      | 3.8.6.final.0 | 3.8.10.final.0 | 3.8.10.final.0 |
# +-------------+---------------+----------------+----------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
outputs = []
time1 = time()
# TRAINING PARENTS FIRST
for pk in parent_maps.keys():
    ret = delayed(train_gisjoin)(pk, True)
    outputs.append(ret)

futures = dask.persist(*outputs)  # trigger computation in the background
results = dask.compute(*futures)
print(f'Time to train one GISJOIN: {time() - time1} s')
# Out:
# Time to train one GISJOIN: 234.45221519470215 s

# %%
print(results)
print(f'No. of results: {len(results)}')
# Out:
# (('G5501210', GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G1600390', GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G1301930', GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G3500030', GradientBoostingRegressor(max_depth=2, min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G2001930', GradientBoostingRegressor(max_depth=2, min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G1800450', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G2001630', GradientBoostingRegressor(max_depth=2, min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G1201010', GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G4803730', GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G0801090', GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G3500270', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G3600090', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G3400150', GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G1901670', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G5300650', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G1201210', GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G4100410', GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G4802570', GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G0600370', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G3901290', GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G1300430', GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G2000450', GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G0501470', GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G0801010', GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G1600450', GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G4200810', GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G2001350', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G2801470', GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G3100690', GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G5300330', GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G0800790', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G5000230', GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G0201950', GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G5600110', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G3601190', GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G1900910', GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G2000530', GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G1700690', GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G5600350', GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G2300110', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G1301950', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G3700470', GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G2800390', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G4804950', GradientBoostingRegressor(max_depth=2, min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G2600970', GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G4900210', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G1300050', GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G2200490', GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)), ('G4200030', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G4804470', GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G0600790', GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G5100710', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G4900290', GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0)), ('G1300350', GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0)), ('G1901790', GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0)))
# No. of results: 55

# %%
for sm in results:
    (gis_join, model) = sm
    saved_models[gis_join] = model

print(saved_models)
pickle.dump(saved_models, open('parent_models.pkl', 'wb'))
# Out:
# {'G5501210': GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G1600390': GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G1301930': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3500030': GradientBoostingRegressor(max_depth=2, min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2001930': GradientBoostingRegressor(max_depth=2, min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1800450': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G2001630': GradientBoostingRegressor(max_depth=2, min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201010': GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G4803730': GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G0801090': GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G3500270': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G3600090': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G3400150': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1901670': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G5300650': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G1201210': GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G4100410': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802570': GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G0600370': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G3901290': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1300430': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2000450': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0501470': GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G0801010': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1600450': GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G4200810': GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G2001350': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G2801470': GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G3100690': GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G5300330': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0800790': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G5000230': GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G0201950': GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G5600110': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G3601190': GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G1900910': GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G2000530': GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G1700690': GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G5600350': GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G2300110': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G1301950': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G3700470': GradientBoostingRegressor(max_depth=2, min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G2800390': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G4804950': GradientBoostingRegressor(max_depth=2, min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2600970': GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G4900210': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G1300050': GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G2200490': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4200030': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G4804470': GradientBoostingRegressor(min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G0600790': GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G5100710': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G4900290': GradientBoostingRegressor(max_depth=2, min_samples_split=50, n_estimators=600,
#                           random_state=0), 'G1300350': GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0), 'G1901790': GradientBoostingRegressor(min_samples_split=15, n_estimators=600,
#                           random_state=0)}

# %%
time2 = time()
print(f'Time Taken to build parent models: {time2 - time1} s')
# Out:
# Time Taken to build parent models: 239.24467301368713 s
# distributed.client - ERROR - Failed to reconnect to scheduler after 10.00 seconds, closing client
# _GatheringFuture exception was never retrieved
# future: <_GatheringFuture finished exception=CancelledError()>
# asyncio.exceptions.CancelledError
