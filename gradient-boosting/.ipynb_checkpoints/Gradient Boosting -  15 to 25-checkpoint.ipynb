# %%
from random import sample
from time import time
import pandas as pd
import pymongo
from sklearn import ensemble
import numpy as np
import os
from sklearn.model_selection import cross_val_score, train_test_split, KFold
from sklearn.metrics import mean_squared_error
from math import sqrt

import random

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV

# %% [markdown]
# <h3><u>GROUPING CLUSTERS FROM CSV</u></h3>

# %%
df_clusters = pd.read_csv("~/ucc-21/clusters.csv")

# %%
time1 = time()

df_clusters

gk = df_clusters.groupby('cluster_id')

gk

# %%
parent_maps = {}
child_to_parent = {}

for name, group in gk:
    row = group[group.distance == group.distance.min()]
    row_max = group[group.distance == group.distance.max()]
    
    children = list(group.gis_join)
    distances = list(group.distance)
    
    dist_min = row['distance'].item()
    dist_max = row_max['distance'].item()
    
    pg = str(row['gis_join'].item())
    
    parent_index = children.index(pg)
    children.pop(parent_index)
    distances.pop(parent_index)
    
    inner_dict = {}
    inner_dict['dist_min'] = dist_min
    inner_dict['dist_max'] = dist_max
    inner_dict['children'] = children
    inner_dict['distances'] = distances
    
    parent_maps[pg] = inner_dict
    
    for c in children:
        child_to_parent[c] = pg
    
                           
print(parent_maps)
print(child_to_parent)
# Out:
# {'G0800650': {'dist_min': 391.0929075096816, 'dist_max': 424.1308766333965, 'children': ['G4000770', 'G0601150', 'G4500190', 'G1301230', 'G3800270', 'G3800590', 'G1801290', 'G1701070', 'G1701170', 'G5101770', 'G4801290', 'G4001390', 'G1900290', 'G3600090', 'G5100030', 'G2701570', 'G3100750', 'G2601090', 'G4600470', 'G4800810', 'G4600910', 'G1700650', 'G1801330', 'G3901690', 'G0600670', 'G0600110', 'G4804710', 'G4805070', 'G2001390', 'G3701790', 'G2900550', 'G4700350', 'G2700290', 'G4600070', 'G4700210', 'G4800130', 'G3901390', 'G4001470', 'G4804130', 'G4500630', 'G4800590', 'G2400450', 'G0501310', 'G1702010', 'G0100710', 'G4804790', 'G2300190', 'G4802790', 'G4000290', 'G4001310', 'G1301390', 'G5500590', 'G4201270', 'G2400170', 'G4001110', 'G5100910', 'G2001650', 'G3600250', 'G3101370', 'G2601230', 'G4200630', 'G0500170', 'G2600290', 'G2800510', 'G4600830', 'G5101250', 'G0100750', 'G4700850', 'G2601350', 'G1302430', 'G4001410', 'G4701830', 'G2201230', 'G2801290', 'G4000490', 'G3901490', 'G1900210', 'G2000230', 'G2900810', 'G1300110', 'G2800470', 'G1701590', 'G5500570', 'G1302590', 'G1801550', 'G5100490', 'G1700830', 'G4802630', 'G3101530', 'G0600590', 'G2701110', 'G0500390', 'G0800170', 'G3701270', 'G3701710', 'G4900110', 'G0600190', 'G5100610', 'G0500290', 'G4600890', 'G2902150', 'G2200810', 'G0100390', 'G5600030', 'G2700330', 'G1901970', 'G5300690', 'G4701730', 'G2101630', 'G2700730', 'G2901610', 'G5300230', 'G0801030', 'G0800110', 'G4800870', 'G1600130', 'G2000710', 'G3600310', 'G0500250', 'G2000650', 'G5500910', 'G2600730', 'G1200650', 'G3000410', 'G4802070', 'G2800750', 'G4001150', 'G3100330', 'G4700510', 'G5400910', 'G2100290', 'G3900530', 'G1700330', 'G3600330', 'G2500170', 'G1303010', 'G3000470', 'G4701250', 'G5100360', 'G4001450', 'G3101110', 'G3700250', 'G3701950', 'G3100270', 'G3900610', 'G5300470', 'G0600390', 'G1300330', 'G2200950', 'G2800330', 'G0800870', 'G4201170', 'G3100310', 'G3101830', 'G2701410', 'G5401010', 'G2101070', 'G2900210', 'G2801590', 'G1300290', 'G2600550', 'G3100150', 'G5106700', 'G2901470', 'G1302230', 'G4804830', 'G3200310', 'G3901190', 'G3500510', 'G3700150', 'G3100650', 'G2601370', 'G4701390', 'G2400090', 'G4803670', 'G0500990', 'G3400110', 'G2600650', 'G1200670', 'G2901830', 'G0501410', 'G3500110', 'G0800470', 'G2000690', 'G3000170', 'G4201290', 'G3101190', 'G4000410', 'G3900670', 'G1700050', 'G4800470', 'G0100430', 'G5300010', 'G5100730', 'G3300170', 'G3700210', 'G1200850', 'G3901370', 'G5107700', 'G1800530', 'G4800210', 'G2000770', 'G4100270', 'G1801410', 'G5100270', 'G1700870', 'G2100030', 'G3100470', 'G1303190', 'G3601090', 'G1800270', 'G5100150', 'G0100330', 'G2900450', 'G2800450', 'G2100610', 'G0800710', 'G4800770', 'G3900230', 'G5101590', 'G2901950', 'G3500590', 'G1701870', 'G1300270', 'G5100050', 'G1901430', 'G5100230', 'G2800190', 'G3601030', 'G4800090', 'G0501230', 'G3600810', 'G5300530', 'G2601190', 'G3800010', 'G4801490', 'G2801110', 'G3900630', 'G4701170', 'G4600670', 'G1600650', 'G4803290', 'G5300250', 'G1302830', 'G1201330', 'G0100030', 'G2001170', 'G3901090', 'G2700810', 'G5100710', 'G2800650', 'G3101630', 'G4701330', 'G4701270', 'G4600510', 'G4800910', 'G5501250', 'G2100130', 'G2101090', 'G4701630', 'G4700130', 'G4500530', 'G1901230', 'G1900630', 'G0600230', 'G2700350', 'G1301130', 'G2600570', 'G5100310', 'G4001050', 'G2901590', 'G3800690', 'G3700930', 'G0101070', 'G3900070', 'G3100390', 'G2701390', 'G1701410', 'G1700510', 'G1701510', 'G3101690', 'G2400190', 'G2001710', 'G2600810', 'G1800110', 'G4100230', 'G2801050', 'G2100370', 'G3000710', 'G2801150', 'G1800330', 'G5500790', 'G3601230', 'G1300710', 'G2102210', 'G4804570', 'G4801250', 'G0100910', 'G1801390', 'G3600850', 'G0800910', 'G2102270', 'G2101350', 'G5400250', 'G3000290', 'G1701450', 'G0800250', 'G0600310', 'G4804350', 'G2405100', 'G5300710', 'G4201130', 'G2800270', 'G4803370', 'G3101510', 'G1302450', 'G4100390', 'G1900110', 'G4600150', 'G4000630', 'G2300050', 'G2600170', 'G1302650', 'G3800350', 'G0400170', 'G4802450', ...
# {'G4000770': 'G0800650', 'G0601150': 'G0800650', 'G4500190': 'G0800650', 'G1301230': 'G0800650', 'G3800270': 'G0800650', 'G3800590': 'G0800650', 'G1801290': 'G0800650', 'G1701070': 'G0800650', 'G1701170': 'G0800650', 'G5101770': 'G0800650', 'G4801290': 'G0800650', 'G4001390': 'G0800650', 'G1900290': 'G0800650', 'G3600090': 'G0800650', 'G5100030': 'G0800650', 'G2701570': 'G0800650', 'G3100750': 'G0800650', 'G2601090': 'G0800650', 'G4600470': 'G0800650', 'G4800810': 'G0800650', 'G4600910': 'G0800650', 'G1700650': 'G0800650', 'G1801330': 'G0800650', 'G3901690': 'G0800650', 'G0600670': 'G0800650', 'G0600110': 'G0800650', 'G4804710': 'G0800650', 'G4805070': 'G0800650', 'G2001390': 'G0800650', 'G3701790': 'G0800650', 'G2900550': 'G0800650', 'G4700350': 'G0800650', 'G2700290': 'G0800650', 'G4600070': 'G0800650', 'G4700210': 'G0800650', 'G4800130': 'G0800650', 'G3901390': 'G0800650', 'G4001470': 'G0800650', 'G4804130': 'G0800650', 'G4500630': 'G0800650', 'G4800590': 'G0800650', 'G2400450': 'G0800650', 'G0501310': 'G0800650', 'G1702010': 'G0800650', 'G0100710': 'G0800650', 'G4804790': 'G0800650', 'G2300190': 'G0800650', 'G4802790': 'G0800650', 'G4000290': 'G0800650', 'G4001310': 'G0800650', 'G1301390': 'G0800650', 'G5500590': 'G0800650', 'G4201270': 'G0800650', 'G2400170': 'G0800650', 'G4001110': 'G0800650', 'G5100910': 'G0800650', 'G2001650': 'G0800650', 'G3600250': 'G0800650', 'G3101370': 'G0800650', 'G2601230': 'G0800650', 'G4200630': 'G0800650', 'G0500170': 'G0800650', 'G2600290': 'G0800650', 'G2800510': 'G0800650', 'G4600830': 'G0800650', 'G5101250': 'G0800650', 'G0100750': 'G0800650', 'G4700850': 'G0800650', 'G2601350': 'G0800650', 'G1302430': 'G0800650', 'G4001410': 'G0800650', 'G4701830': 'G0800650', 'G2201230': 'G0800650', 'G2801290': 'G0800650', 'G4000490': 'G0800650', 'G3901490': 'G0800650', 'G1900210': 'G0800650', 'G2000230': 'G0800650', 'G2900810': 'G0800650', 'G1300110': 'G0800650', 'G2800470': 'G0800650', 'G1701590': 'G0800650', 'G5500570': 'G0800650', 'G1302590': 'G0800650', 'G1801550': 'G0800650', 'G5100490': 'G0800650', 'G1700830': 'G0800650', 'G4802630': 'G0800650', 'G3101530': 'G0800650', 'G0600590': 'G0800650', 'G2701110': 'G0800650', 'G0500390': 'G0800650', 'G0800170': 'G0800650', 'G3701270': 'G0800650', 'G3701710': 'G0800650', 'G4900110': 'G0800650', 'G0600190': 'G0800650', 'G5100610': 'G0800650', 'G0500290': 'G0800650', 'G4600890': 'G0800650', 'G2902150': 'G0800650', 'G2200810': 'G0800650', 'G0100390': 'G0800650', 'G5600030': 'G0800650', 'G2700330': 'G0800650', 'G1901970': 'G0800650', 'G5300690': 'G0800650', 'G4701730': 'G0800650', 'G2101630': 'G0800650', 'G2700730': 'G0800650', 'G2901610': 'G0800650', 'G5300230': 'G0800650', 'G0801030': 'G0800650', 'G0800110': 'G0800650', 'G4800870': 'G0800650', 'G1600130': 'G0800650', 'G2000710': 'G0800650', 'G3600310': 'G0800650', 'G0500250': 'G0800650', 'G2000650': 'G0800650', 'G5500910': 'G0800650', 'G2600730': 'G0800650', 'G1200650': 'G0800650', 'G3000410': 'G0800650', 'G4802070': 'G0800650', 'G2800750': 'G0800650', 'G4001150': 'G0800650', 'G3100330': 'G0800650', 'G4700510': 'G0800650', 'G5400910': 'G0800650', 'G2100290': 'G0800650', 'G3900530': 'G0800650', 'G1700330': 'G0800650', 'G3600330': 'G0800650', 'G2500170': 'G0800650', 'G1303010': 'G0800650', 'G3000470': 'G0800650', 'G4701250': 'G0800650', 'G5100360': 'G0800650', 'G4001450': 'G0800650', 'G3101110': 'G0800650', 'G3700250': 'G0800650', 'G3701950': 'G0800650', 'G3100270': 'G0800650', 'G3900610': 'G0800650', 'G5300470': 'G0800650', 'G0600390': 'G0800650', 'G1300330': 'G0800650', 'G2200950': 'G0800650', 'G2800330': 'G0800650', 'G0800870': 'G0800650', 'G4201170': 'G0800650', 'G3100310': 'G0800650', 'G3101830': 'G0800650', 'G2701410': 'G0800650', 'G5401010': 'G0800650', 'G2101070': 'G0800650', 'G2900210': 'G0800650', 'G2801590': 'G0800650', 'G1300290': 'G0800650', 'G2600550': 'G0800650', 'G3100150': 'G0800650', 'G5106700': 'G0800650', 'G2901470': 'G0800650', 'G1302230': 'G0800650', 'G4804830': 'G0800650', 'G3200310': 'G0 ...

# %% [markdown]
# <h3><u>CONSTANTS AND HELPER FUNCTIONS</u></h3>

# %%
sample_min = 0.05
sample_max = 0.25

query_collection = "macav2"

mongo_urls = [
    'mongodb://lattice-100:27018/',
    'mongodb://lattice-101:27018/',
    'mongodb://lattice-102:27018/',
    'mongodb://lattice-103:27018/',
    'mongodb://lattice-104:27018/'
]

mongo_db_name = "sustaindb"
query_fild = "gis_join"
train_test = 0.8


training_labels = ["min_surface_downwelling_shortwave_flux_in_air", "max_surface_downwelling_shortwave_flux_in_air",
                   "max_specific_humidity", "min_max_air_temperature", "max_max_air_temperature"]
target_labels = ["max_min_air_temperature"]


# QUERY projection
client_projection = {}
for val in training_labels:
    client_projection[val] = 1
for val in target_labels:
    client_projection[val] = 1

# %% [markdown]
# <h1><u>MODELING</u></h1>

# %%
saved_models = {}

# ACTUAL QUERYING
def query_sustaindb(query_gisjoin, sustain_db):
    sustain_collection = sustain_db[query_collection]
    client_query = {query_fild: query_gisjoin}
    query_results = list(sustain_collection.find(client_query, client_projection)) 
    return list(query_results)

# SAMPLE FROM QUERY RESULTS
def data_sampling(query_results, exhaustive, sample_percent=1):
    if exhaustive:
        all_data = query_results
    else:
        data_size = int(len(query_results) * sample_percent)
        all_data = sample(query_results, data_size)

    return pd.DataFrame(all_data)

# GET SAMPLE % BASED ON DISTANCE FROM CENTROID
def get_sample_percent(gis_join):
    parent_gis = child_to_parent[gis_join]
    inner_dict = parent_maps[parent_gis]
    d_max = inner_dict['dist_max']
    d_min = inner_dict['dist_min']
    children = inner_dict['children']
    distances = inner_dict['distances']
    
    my_index = children.index(gis_join)
    my_distance = distances[my_index]
    
    frac = (my_distance - d_min)/(d_max - d_min)
    
    perc = sample_min + (sample_max - sample_min) * frac
    
    perc*=100
    perc = int(perc)
    perc = perc - (perc%5)
    
    perc = perc/100
    return perc


# GET PERCENTAGE DISTANCE FROM CENTROID
def get_distance_percentage(gis_join):
    parent_gis = child_to_parent[gis_join]
    inner_dict = parent_maps[parent_gis]
    d_max = inner_dict['dist_max']
    d_min = inner_dict['dist_min']
    children = inner_dict['children']
    distances = inner_dict['distances']
    
    my_index = children.index(gis_join)
    my_distance = distances[my_index]
    
    frac = (my_distance - d_min)/(d_max - d_min)
    
    return frac * 100

def exhaustive_training(X,Y, gis_join):
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
    
    param_grid = {'max_depth': [2, 3], 'min_samples_split': [15, 20, 50]}
#     base_est = ensemble.RandomForestRegressor(random_state=0)
    base_est = ensemble.GradientBoostingRegressor(random_state=0)
    sh = HalvingGridSearchCV(base_est, param_grid, cv=5, verbose=1, 
                             factor=2, resource='n_estimators', max_resources=600).fit(X, pd.Series.ravel(Y))
    
    clf_best = sh.best_estimator_
    rmse = sqrt(mean_squared_error(pd.Series.ravel(y_test), clf_best.predict(X_test)))
    
    print("PARENT GISJOIN: ", gis_join, "RMSE:", rmse)
    return clf_best
    

def sampled_training(X, Y, gis_join, saved_models):
    parent_gis = child_to_parent[gis_join]
    clf = saved_models[parent_gis]
    
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
    
    clf.fit(X_train, pd.Series.ravel(y_train))

    rmse = sqrt(mean_squared_error(pd.Series.ravel(y_test), clf.predict(X_test)))
    
    print("CHILD GISJOIN: ", gis_join, "RMSE:", rmse)
    return clf
    

def train_gisjoin(gis_join, exhaustive=True, saved_models={}):
    mongo_url = mongo_urls[random.randint(0, len(mongo_urls) - 1)]
    sustainclient = pymongo.MongoClient(mongo_url)
    sustain_db = sustainclient[mongo_db_name]

    sample_percent = 1
    if not exhaustive:
        #print("SAMPLED CHILD TRAINING.....")
        sample_percent = get_sample_percent(gis_join)
        
        
    #QUERY
    results = query_sustaindb(gis_join, sustain_db)
    
    df_sampled = data_sampling(results, exhaustive, sample_percent)
    
    Y = df_sampled.loc[:,target_labels]
    X = df_sampled.loc[:, training_labels]
    #print(X.shape, Y.shape)
    
    if exhaustive:
        clf = exhaustive_training(X,Y, gis_join)
    else:
        clf = sampled_training(X,Y, gis_join, saved_models)
    
    #saved_models[gis_join] = clf
    return (gis_join,clf)
    
#'G1303070': 'G0800010'
#train_gisjoin('G0800010', True)
#train_gisjoin('G1303070', False)

# %%
sampling_perc_to_children_map = {}
for ck in child_to_parent.keys():
#     perc = get_distance_percentage(ck)
    perc = get_sample_percent(ck) * 100
    sampling_perc_to_children_map[ck] = perc
    
keys_0_to_15 = []
keys_15_to_25 = []
    
for gis_join, perc in sampling_perc_to_children_map.items():
    if perc < 15:
        keys_0_to_15.append(gis_join)
    elif perc > 15:
        keys_15_to_25.append(gis_join)
    
print(f'keys_0_to_15: {len(keys_0_to_15)}')
print(f'keys_15_to_25: {len(keys_15_to_25)}')
# Out:
# keys_0_to_15: 1870
# keys_15_to_25: 175

# %%
import dask
from dask import delayed
from dask.distributed import Client

client = Client('localhost:9010')
# Out:
# /s/parsons/b/others/sustain/.local/lib/python3.8/site-packages/distributed/client.py:1183: VersionMismatchWarning: Mismatched versions found
#
# +-------------+---------------+----------------+----------------+
# | Package     | client        | scheduler      | workers        |
# +-------------+---------------+----------------+----------------+
# | blosc       | 1.10.4        | 1.10.2         | 1.10.2         |
# | dask        | 2021.07.0     | 2021.08.0      | 2021.08.0      |
# | distributed | 2021.07.0     | 2021.08.0      | 2021.08.0      |
# | numpy       | 1.21.0        | 1.21.1         | 1.21.1         |
# | python      | 3.8.6.final.0 | 3.8.10.final.0 | 3.8.10.final.0 |
# +-------------+---------------+----------------+----------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
import pickle
saved_models = pickle.load(open('parent_models.pkl', 'rb'))

# %%
outputs2 = []

# TRAINING CHILDREN NEXT
# for ck in child_to_parent.keys():
time1 = time()
for ck in keys_15_to_25:
    ret = delayed(train_gisjoin)(ck, False, saved_models)
    outputs2.append(ret)
    break

futures2 = dask.persist(*outputs2)  # trigger computation in the background
results2 = dask.compute(*futures2)

for sm in results2:
    (gis_join, model) = sm
    saved_models[gis_join] = model

print(saved_models)
print(f'time taken : {time() - time1} s')
# Out:
# CHILD GISJOIN:  G4805070 RMSE: 1.8752110725512565
# {'G0800650': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0600750': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4805070': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800130': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804790': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2800470': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200650': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200950': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200670': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800470': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200850': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800210': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2800450': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4801490': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201330': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0100030': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800910': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802450': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0400120': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800430': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0600730': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200950': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800610': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200090': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804630': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200450': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802970': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1301270': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804930': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4803250': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4803110': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2201030': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2201050': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200690': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802550': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0600270': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201190': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200230': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200430': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200860': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200630': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200310': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4801630': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800070': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200710': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200150': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200970': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200990': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4803210': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200570': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200230': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2201090': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201010': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0600710': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804270': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200550': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4801770': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804530': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201050': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200010': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4803550': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200470': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200270': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201070': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4801230': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200530': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200930': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3200170': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201210': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200450': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802830': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0400210': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4801570': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4803230': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200350': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800250': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800710': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200410': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4803610': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200610': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200510': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800410': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802390': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200070': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201170': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4801850': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200190': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800570': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0400070': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201270': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0400270': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200750': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4801270': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200830': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804430': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200530': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1302990': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4803390': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1301790': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4801310': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201290': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200810': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200990': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4801870': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201110': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200210': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2201130': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800150': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201130': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804770': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4801670': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4803770': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0400130': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200010': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201030': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201250': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2800590': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1300390': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802910': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800290': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802850': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200330': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4805050': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804650': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200490': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G3200030': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200930': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200070': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804730': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0600650': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200570': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201310': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200370': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802490': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200110': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0400250': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804810': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1300490': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201090': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200970': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0600250': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804690': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200710': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0600290': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2201010': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200510': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4801750': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1301910': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802730': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201230': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0400150': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200910': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802010': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804890': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200750': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0100970': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802610': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1201150': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800890': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200890': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200770': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200890': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200170': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200050': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G2200870': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802150': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802470': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4804090': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4803910': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800550': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802870': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200030': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4802710': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G0400190': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200790': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G4800390': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0), 'G1200190': GradientBoostingRegressor(min_samples_split=20, n_estimators=600,
#                           random_state=0)}
# time taken : 1.1274070739746094 s

# %%
time2 = time()
print(f'Time Taken: {time2 - time1} s')
# Out:
# Time Taken: 38.9023175239563 s
# distributed.client - ERROR - Failed to reconnect to scheduler after 10.00 seconds, closing client
# _GatheringFuture exception was never retrieved
# future: <_GatheringFuture finished exception=CancelledError()>
# asyncio.exceptions.CancelledError
